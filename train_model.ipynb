# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
#Data Pre-Processing 
#loading the dataset to a pandas dataframe

fake_news_dataset = pd.read_csv("Data/fake.csv")
true_news_dataset = pd.read_csv("Data/true.csv")

# %%
fake_news_dataset
true_news_dataset
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %%
fake_news_dataset['label']= 0
true_news_dataset['label']= 1

# %%
news_dataset = pd.concat([true_news_dataset , fake_news_dataset] , ignore_index = True)
news_dataset
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 44893  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 44894  21st Century Wire says It s a familiar theme. ...   Middle-east
# 44895  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 44896  21st Century Wire says Al Jazeera America will...   Middle-east
# 44897  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  label
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 44893    January 16, 2016      0
# 44894    January 16, 2016      0
# 44895    January 15, 2016      0
# 44896    January 14, 2016      0
# 44897    January 12, 2016      0
#
# [44898 rows x 5 columns]

# %%
news_dataset = news_dataset.sample(frac=1).reset_index(drop = True)
news_dataset.head()
# Out:
#                                                title  \
# 0   Dumbass Alaska Lawmaker Claims Women Have Abo...
# 1  North Korea deepening economic, diplomatic iso...
# 2  Turkey, Iraq agree on opening second border ga...
# 3  Kenya vote in balance as crisis deepens after ...
# 4   WATCH: Female Cop Halts Sex Offender’s Violen...
#
#                                                 text    subject  \
# 0  Generations upon generations of incest have ap...       News
# 1  MEXICO CITY (Reuters) - U.S. Defense Secretary...  worldnews
# 2  ISTANBUL (Reuters) - Turkey and Iraq have agre...  worldnews
# 3  NAIROBI (Reuters) - Kenya lurched deeper into ...  worldnews
# 4  Earlier in January, 31-year-old Michael Cox wa...       News
#
#                   date  label
# 0          May 5, 2017      0
# 1  September 15, 2017       1
# 2    October 26, 2017       1
# 3    October 11, 2017       1
# 4     February 1, 2016      0

# %%
news_dataset.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news_dataset['content'] = news_dataset.title + " " + news_dataset.text

# %%
news_dataset = news_dataset[['content' , 'label']]
news_dataset.head()
# Out:
#                                              content  label
# 0   Dumbass Alaska Lawmaker Claims Women Have Abo...      0
# 1  North Korea deepening economic, diplomatic iso...      1
# 2  Turkey, Iraq agree on opening second border ga...      1
# 3  Kenya vote in balance as crisis deepens after ...      1
# 4   WATCH: Female Cop Halts Sex Offender’s Violen...      0

# %%
#Stemming

port_stem = PorterStemmer()

# %%
port_stem = PorterStemmer()
stop_words = set(stopwords.words('english'))

def stemming(content):
    # Remove non-alphabet characters and lowercase
    content = re.sub('[^a-zA-Z]', ' ', content).lower().split()
    
    # Remove stopwords and stem
    content = [port_stem.stem(word) for word in content if word not in stop_words]
    
    return ' '.join(content)

# %%
from tqdm import tqdm
tqdm.pandas()

news_dataset['content'] = news_dataset['content'].progress_apply(stemming)
# Out:
# 100%|██████████| 44898/44898 [09:46<00:00, 76.61it/s]

# %%
news_dataset.to_csv('Data/stemmed_dataset.csv', index=False)

# %%
news_dataset = pd.read_csv('Data/stemmed_dataset.csv')

# %%
news_dataset
# Out:
#                                                  content  label
# 0      dumbass alaska lawmak claim women abort free t...      0
# 1      north korea deepen econom diplomat isol matti ...      1
# 2      turkey iraq agre open second border gate turki...      1
# 3      kenya vote balanc crisi deepen odinga quit nai...      1
# 4      watch femal cop halt sex offend violent rampag...      0
# ...                                                  ...    ...
# 44893  defi trump iran say boost missil capabl london...      1
# 44894  state file lawsuit challeng trump decis dreame...      1
# 44895  trump brag number peopl come inaugur realiz pr...      0
# 44896  trump consid democrat senat manchin energi sec...      1
# 44897  priceless race baiter john lewi bombard heckle...      0
#
# [44898 rows x 2 columns]

# %%
#Seperating the data and label

X = news_dataset['content'].values
Y = news_dataset['label'].values

# %%
print(X)
# Out:
# ['trump meet senat ernst amid vice presidenti specul trump meet senat ernst amid vice presidenti specul washington reuter presumpt republican presidenti nomine donald trump met u senat joni ernst iowa monday feed specul could short list consider vice presidenti run mate fox news report ernst told network new york real estat mogul good convers continu share insight donald need strengthen economi keep nation safe ensur america alway strong stabil forc around globe said trump tweet would meet ernst new jersey done great job senat iowa said trump met indiana governor mike penc also mention potenti run mate wife saturday republican sourc told reuter former hous repres speaker newt gingrich new jersey governor chri christi top trump vice presidenti short list name watch includ u senat bob corker tennesse jeff session alabama governor mari fallin oklahoma sourc said'
#  'testi sheila jackson lee challeng trump budget director doctor director video testi sheila jackson lee challeng trump budget director doctor director video mick mulvaney one smart cooki fantast job cut cut need made congress complain cut voter base favorit item listen grandstand jackson lee cut medicaid beg medicaid grandstand sicken went downhil jackson lee want tri make mulvaney uncar guy total bulli one smart cook mulvaney gave detail budget cut fantast press confer highli recommend entir video offic manag budget omb director mick mulvaney outlin structur intent purpos trump administr fiscal year budget taxpay budget best part great news confer report ask cut climat scienc program mark mick mulvaney rip report awesom recommend entir video see trump hire one smart cooki mick mulvaney know budget handl press beauti'
#  'play fire ten thousand refus leav bali volcano home play fire ten thousand refus leav bali volcano home karangasem indonesia reuter ten thousand villag indonesian holiday island bali refus evacu km six mile danger zone around erupt volcano put fate hand god simpli stay put protect home livestock glow metr mount agung consid sacr mani hindu major island start spew huge column ash weekend constant tremor volcan mud flow sinc search rescu team make daili foray zone say refus leav cattl unattend other spiritu reason govern clear evacu order peopl slow act want stay said gede ardana head bali search rescu agenc cannot forc held respons need convinc cattl farmer ketut suwart question stay put thick ash fall around us could smell sulfur scare decid leav immedi said suwart stay evacu camp outsid danger zone suwart father recal last time mount agung explod kill peopl pyroclast flow made hot ga volcan matter race mountain sutopo purwo nugroho disast mitig agenc said peopl heed advic take shelter estim popul danger area mani ika wardani sleep famili evacu center night day return cattl farm km north volcano day least see volcano uncomfort sleep night earthquak loud explos would caus panic said would drive motorbik night road narrow safer spend night evacu center say peopl five km crater refus evacu stubborn said surviv believ right govern set radio station chat group social media warn peopl risk mani peopl made decis stay insid exclus zone clearli danger said sutopo purwo nugroho spokesman disast manag agenc other includ tourist take unnecessari risk tri take selfi close possibl offici say last month frenchman share video crater edg social media septemb author first rais warn alert highest level exclus zone km impos prompt nearli leav major erupt occur mani return warn statu lower author rais warn level week mani reluct move mount agung follow frequent trend like continu increas explos rate larg nobodi know said dr carmen solana volcanologist univers portsmouth presid joko widodo wednesday urg peopl leav exclus zone late must victim said'
#  ...
#  'japan defens chief warn possibl north korea provoc octob japan defens chief warn possibl north korea provoc octob tokyo reuter japanes defens minist itsunori onodera urg caution friday provoc possibl north korea oct start lower hous elect campaign japan coincid one north main anniversari tension risen korean peninsula sinc reclus north korea conduct sixth power nuclear test sept lead new round sanction unanim vote unit nation secur council u presid donald trump sinc trade insult north korean leader rais stake even north korea often mark signific event calendar conduct weapon test fifth nuclear test last year sept found anniversari onodera said oct mark import anniversari north korea date north celebr found north korean communist parti understand import anniversari north korea would like maintain sens urgenc onodera told report oct also coincident day campaign begin japan parliament lower hous elect day later prime minist shinzo abe dissolv chamber thursday onodera warn echo comment south korean nation secur advis chung eui yong said meet presid moon jae thursday expect pyongyang act around oct gave detail nl n oct mark start china import communist parti congress north korea conduct seri ballist missil launch year includ two launch japan recent week defianc intern pressur china north korea main alli trade partner urg dialogu way resolv crisi although japan tend support washington robust approach abe said time appli pressur north korea rather dialogu order convinc north korea end nuclear missil program'
#  'puerto rico power grid face gener threat hurrican maria puerto rico power grid face gener threat hurrican maria reuter hurrican maria cours tuesday slam puerto rico direct hit could devast island underfund power grid still recov hurrican irma two week ago categori storm top end five step saffir simpson scale could strain resourc island power provid puerto rico electr power author prepa util file bankruptci juli year underinvest yield system call degrad unsaf maria expect strike island wednesday wind mile per hour km per hour u nation hurrican center nhc said irma graze puerto rico knock power million prepa million custom accord u energi depart power restor island power plant sever damag maria howev could first major hurrican defin categori higher make landfal sinc georg said todd crawford chief meteorologist weather compani ibm compani could first categori sinc san felip ii kill peopl island gener seen hurrican like sinc san felip ii unpreced atmospher system said puerto rico governor ricardo rossel statement tuesday island could face outag week strain resourc util whose power plant median age year compar industri averag year frequent power outag prepa said draft fiscal plan releas april year underinvest led sever degrad infrastructur even energi system prime condit know still would difficult said nydia suarez work cne group think tank live island plan stay son guaynabo farther inland home san juan util declar bankruptci juli due billion hole deepen lengthi recess island inconsist manag ineffect collect island power price alreadi higher u state hawaii accord u energi depart reluct rais rate gener addit revenu increas capit expenditur island popul bit depress said rick donner vice presid senior credit offic credit rate agenc moodi investor servic new york prepa use plan use irma execut director ricardo ramo said news releas first energ hospit water plant industri util said refil fuel tank worker collect debri trim tree damag irma near transmiss line depart energi said work american public power author appa prepa feder emerg manag agenc fema get mutual aid worker puerto rico elsewher day without electr georg think power system wors fragil expect time without power cne group suarez said'
#  'watch cnn nail trump lie would never demand loyalti watch cnn nail trump lie would never demand loyalti donald trump got caught lie video prove former fbi director jame comey testifi oath senat thursday recal trump demand loyalti ask drop investig michael flynn trump tie russia presid said need loyalti expect loyalti comey testifi ask abc report jon karl demand comey loyalti trump deni whole thing pretend never demand loyalti anyon entir life said thing oath karl began would will speak oath give version event one hundr percent trump repli say oath hardli know man go say want pledg allegi would would ask man pledg allegi oath mean think hardli know man make sens say say trump say oath would would commit perjuri cnn prove play video trump campaign trail florida ask peopl crowd rais hand pledg loyalti keep mind trump never met anyon audienc sever discuss meet comey word comey complet stranger will ask crowd random peopl pledg allegi would certainli will demand loyalti comey damn video via youtub yet proof trump liar zero credibl say anyth save ass featur imag via olivi doulieri pool getti imag']

# %%
print(Y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
X.shape
# Out:
# (44898,)

# %%
#Converting the textual data to numerical data

vectorizer =  TfidfVectorizer()
vectorizer.fit(X)

X = vectorizer.transform(X)

# %%
print(X)
# Out:
#   (0, 298)	0.034651144309092476
#   (0, 334)	0.34113191854024966
#   (0, 430)	0.08458216449198613
#   (0, 660)	0.027080118767662347
#   (0, 903)	0.04825731766235165
#   (0, 1758)	0.1790091459178884
#   (0, 2575)	0.02228586254325063
#   (0, 2859)	0.0880302838301916
#   (0, 3186)	0.02695617060694764
#   (0, 3254)	0.03192350154408127
#   (0, 3540)	0.03777104569839314
#   (0, 4301)	0.024613859310058016
#   (0, 4381)	0.04197793727644731
#   (0, 4643)	0.027014233293551473
#   (0, 5023)	0.04508562557559718
#   (0, 5313)	0.050160427202307116
#   (0, 5357)	0.022436971367573923
#   (0, 5438)	0.08207392085591153
#   (0, 7991)	0.03432985003769001
#   (0, 9309)	0.05256655501612637
#   (0, 9861)	0.044858219178672554
#   (0, 10249)	0.033665881311533676
#   (0, 11631)	0.03565892897030223
#   (0, 11930)	0.03351197887808072
#   (0, 12217)	0.05548421676897582
#   :	:
#   (44897, 9454)	0.14531419211008662
#   (44897, 11723)	0.12283760595947181
#   (44897, 12642)	0.20184298362727632
#   (44897, 15406)	0.18363641024842925
#   (44897, 16113)	0.13668339618620948
#   (44897, 18262)	0.22323625516204312
#   (44897, 21363)	0.22635643941572578
#   (44897, 23533)	0.1256933119447256
#   (44897, 26980)	0.21703840488678758
#   (44897, 32012)	0.32315885880630174
#   (44897, 36128)	0.12575717480468193
#   (44897, 38390)	0.13747728179880936
#   (44897, 43917)	0.26224260205322397
#   (44897, 44063)	0.14596912036831788
#   (44897, 44570)	0.11746554334590592
#   (44897, 51292)	0.19873908262081597
#   (44897, 61190)	0.28007348064252596
#   (44897, 61582)	0.14021592602834726
#   (44897, 63095)	0.1478044128458353
#   (44897, 66975)	0.12022863175803643
#   (44897, 78757)	0.1491581697379785
#   (44897, 79536)	0.19791671100011965
#   (44897, 80091)	0.1247539574070947
#   (44897, 83424)	0.09850084780253411
#   (44897, 84745)	0.11273810020143354

# %% [markdown]
# SPLITTING THE DATASET INTO TRAINING AND TESTING DATA

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %% [markdown]
# Training the Model : Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluation

# %%
#Accuracy Score On the training data

X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("The Accuracy Score of the training data:" , training_data_accuracy)
# Out:
# The Accuracy Score of the training data: 0.9918703714015257

# %%
#Accuracy Score On the testing data

X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("The Accuracy Score of the test data:" , test_data_accuracy)
# Out:
# The Accuracy Score of the test data: 0.9880846325167038

# %% [markdown]
# Prediction

# %%
X_new = X_test[0]
prediction = model.predict(X_new)

if (prediction[0] == 0):
  print("The News is Fake.")
else:
  print("The news is Real.")
# Out:
# The news is Real.

# %%
import pickle

# Save the trained model
with open('model/fake_news_model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# Save the fitted TF-IDF vectorizer
with open('model/tfidf_vectorizer.pkl', 'wb') as vec_file:
    pickle.dump(vectorizer, vec_file)
